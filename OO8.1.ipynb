# %%
# suppose you have unstructured texts and you have to clean text then 
# you have to classiy each text into a specific sentiment(positive, Negative ).
# Then you have t create a dataframe in which you will manage 
# first column as text second column as sentiment .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\codings\datasets\noisy_text_dataset_100_rows.csv")

# %%
df
# Out:
#                                                  text
# 0   Check out https://www.amazon.com for great dea...
# 1   <html><body><h1>Welcome</h1></body></html> Row...
# 2   Wow!!! This product is AMAZING!!! :) Row-3 !!!...
# 3   Visit our website at http://example.org/contac...
# 4   <div class='review'>Best purchase ever!!!</div...
# ..                                                ...
# 95  I can't believe this worked... unbelievable!!!...
# 96  Email me at test@example.com!!! Row-97 !!! <br...
# 97  <p>Error 404: Page not found!!!</p> Row-98 !!!...
# 98  Special offer >>> https://shop.example.com/dea...
# 99  The movie was great!!! #awesome #fun Row-100 !...
#
# [100 rows x 1 columns]

# %%
# !pip install textblob
# Out:
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import string
string.punctuation
from textblob import TextBlob

# %%
import re
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'' , text)


def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern. sub(r'' , text)


exclude = string.punctuation

def remove_punc(text):
    for char in exclude:
        text = text.replace(char,'')
    return text

# %%
df['text' ] = df['text'].apply(remove_punc)
df['text' ] = df['text'].apply(remove_url)
df['text' ] = df['text'].apply(remove_html_tags)

# %%
df
# Out:
#                                                  text
# 0   Check out httpswwwamazoncom for great deals Ro...
# 1   htmlbodyh1Welcomeh1bodyhtml Row2  br httpstest...
# 2   Wow This product is AMAZING  Row3  br httpstes...
# 3   Visit our website at httpexampleorgcontactuser...
# 4   div classreviewBest purchase everdiv Row5  br ...
# ..                                                ...
# 95  I cant believe this worked unbelievable Row96 ...
# 96  Email me at testexamplecom Row97  br httpstest...
# 97  pError 404 Page not foundp Row98  br httpstest...
# 98  Special offer  httpsshopexamplecomdeals  Row99...
# 99  The movie was great awesome fun Row100  br htt...
#
# [100 rows x 1 columns]

# %%
def textblob_sentiment_analysis(review):
    sentiment = TextBlob(review).sentiment
    if sentiment.polarity > 0.1 :
        return 'Positive'
    elif sentiment.polarity < -0.1 :
        return 'Negative'
    else:
        return 'Neutral'

# %%
df['Sentiment'] = df['text'].apply(textblob_sentiment_analysis)

# %%
df
# Out:
#                                                  text Sentiment
# 0   Check out httpswwwamazoncom for great deals Ro...  Positive
# 1   htmlbodyh1Welcomeh1bodyhtml Row2  br httpstest...   Neutral
# 2   Wow This product is AMAZING  Row3  br httpstes...  Positive
# 3   Visit our website at httpexampleorgcontactuser...   Neutral
# 4   div classreviewBest purchase everdiv Row5  br ...   Neutral
# ..                                                ...       ...
# 95  I cant believe this worked unbelievable Row96 ...  Negative
# 96  Email me at testexamplecom Row97  br httpstest...   Neutral
# 97  pError 404 Page not foundp Row98  br httpstest...   Neutral
# 98  Special offer  httpsshopexamplecomdeals  Row99...  Positive
# 99  The movie was great awesome fun Row100  br htt...  Positive
#
# [100 rows x 2 columns]
