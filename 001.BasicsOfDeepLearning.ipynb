# %%
# Introduction to Deep Learning ----- >
# Representative Learning --- > input --- > output work complete , hidden process vanish .

# %%
# Workflow of ML
# Data Ingestion --- > Data Cleaninig and Preprocessing -.- > Model selection --- > Model training ---- >
# Model Prediction --- > Performance Evaluation

# %%
# structure :- 

# .(I1)
#             .(H1)
# .(I2)                   .(O1)  ---->  y
#             .(H2)
# .(I3)



# where 
    # I --> input
    # H --> Hidden path 
    # O --> Output
    # y --> final output

# %%
# Backpropagation

# dy/dI1 = (dy/do1 * do1/dH1 * dH1/dI1) + (dy/do1 * do1/dh2 * dh2/dil)
# dy/dI2 = (dy/do1 * do1/dh1 * dh1/di2) + (dy/dol * do1/dh2 * dh2/di2) 
# dy/di3 = (dy/do1 . do1/dh1 * dh1/di3) + (dy/dol * do1/dh2 * dh2/di3)

# %%
# Workflow of Deep Learning ----- >

# Data Ingestion --- > Data Cleaning and Preprocessing ---- >
# Model Sequential Architecture (
    # Input_layer(Number of Neurons , Activation function, Input_dimension),
    # hidden_layer(Number of Neurons, Activation function),
    # Output layer(Number of Neurons based on target column , Activation function)
# )

# %%
# Model.compile(loss_fn , Optimizer , Metrics)
# Model.training
# Model Prediction And Evalaution

# %%
# Neurons --- > Artifical Neurons
# Activation function ---- > Mathematical function who capture Non-linearity into the data .
# loss_fn --- > distance of Actual and Predicted values
# Optimizers ---- > It will reduce the Loss function
